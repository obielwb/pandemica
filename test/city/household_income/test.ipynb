# %% [markdown]
# #### Household Income Mapping
# Utility to extract Campinas city household income, virtualize and distribute it in a matrix.

# %%
import IPython.display


campinas_2015_household_income_image_path = 'data/campinas_2015_household_income.jpg'

IPython.display.Image(campinas_2015_household_income_image_path)

# %%
from PIL import Image
import numpy as np


campinas_2015_household_income_image = Image.open(campinas_2015_household_income_image_path)
campinas_2015_household_income_image_nparray = np.array(campinas_2015_household_income_image)

height, width, _ = campinas_2015_household_income_image_nparray.shape

print(height, width, height * width)
# Out:
# 5796 6940 40224240
